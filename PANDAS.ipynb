# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.3'

# %%
list1=[1,2,3,'Hi']
print(list1)
# Out:
# [1, 2, 3, 'Hi']

# %%
series1=pd.Series(list1)
print(series1)
# Out:
# 0     1
# 1     2
# 2     3
# 3    Hi
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2=pd.Series([1,2,3,4])
series2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
series3=pd.Series([1,2,3],index=['a','b','c'],dtype=float,name='dara')
series3
# Out:
# a    1.0
# b    2.0
# c    3.0
# Name: dara, dtype: float64

# %%
series4=pd.Series(0.5,index=[1,2,3])
series4
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
dict1={1:'a',2:'b'}
series5=pd.Series(dict1)
series5
# Out:
# 1    a
# 2    b
# dtype: object

# %%
print(series3[0])
print(series3[0:1])
# Out:
# 1.0
# a    1.0
# Name: dara, dtype: float64
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8288\1755157044.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(series3[0])

# %%
max(series2)#we can also add two series.
# Out:
# 4

# %%
lol=[[1,2,3],[4,5,6],[7,8,9]]
df1=pd.DataFrame(lol)
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df2=pd.DataFrame({'ID':[1,2,3]})
df2
# Out:
#    ID
# 0   1
# 1   2
# 2   3

# %%
df3=pd.DataFrame([{'a':1,'b':2},{'a':3,'b':2,'c':5}])
df3
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  2  5.0

# %%
df4=pd.DataFrame({'ID':pd.Series([1,2,3]),'ss':pd.Series([3,4,5,6])})
df4
# Out:
#     ID  ss
# 0  1.0   3
# 1  2.0   4
# 2  3.0   5
# 3  NaN   6

# %%
a=pd.read_csv("D:\programming\my pytoh learn\pandas\ABHI.CSV")
a
# Out:
#    S NO TRAIN  SPEED CITY HI BYE COME  GO
# 0     1     A    120    X  A   D    F  FH
# 1     2     B    110    Y  A   D    F  FH
# 2     3     C    100    Z  A   D    F  FH
# 3     4     D     90    W  A   D    F  FH
# 4     5     e     11   as  A   D    F  FH
# 5     6     f     23    d  A   D    F  FH
# 6     7     g     45    g  A   D    F  FH
# 7     8     h     33    h  A   D    F  FH
# 8     9     i     56    j  A   D    F  FH
# 9    10     j      3    k  A   D    F  FH

# %%
a.columns
# Out:
# Index(['S NO', 'TRAIN', 'SPEED', 'CITY', 'HI', 'BYE', 'COME', 'GO'], dtype='object')

# %%
b=pd.read_csv("D:\programming\my pytoh learn\pandas\ABHI.CSV",nrows=2,usecols=[0])
b
# Out:
#    S NO
# 0     1
# 1     2

# %%
c=pd.read_csv("D:\programming\my pytoh learn\pandas\ABHI.CSV",skiprows=1)
c
# Out:
#     1  A  120   X A.1  D  F  FH
# 0   2  B  110   Y   A  D  F  FH
# 1   3  C  100   Z   A  D  F  FH
# 2   4  D   90   W   A  D  F  FH
# 3   5  e   11  as   A  D  F  FH
# 4   6  f   23   d   A  D  F  FH
# 5   7  g   45   g   A  D  F  FH
# 6   8  h   33   h   A  D  F  FH
# 7   9  i   56   j   A  D  F  FH
# 8  10  j    3   k   A  D  F  FH

# %%
c=pd.read_csv("D:\programming\my pytoh learn\pandas\ABHI.CSV",skiprows=[2,3])
c
# Out:
#    S NO TRAIN  SPEED CITY HI BYE COME  GO
# 0     1     A    120    X  A   D    F  FH
# 1     4     D     90    W  A   D    F  FH
# 2     5     e     11   as  A   D    F  FH
# 3     6     f     23    d  A   D    F  FH
# 4     7     g     45    g  A   D    F  FH
# 5     8     h     33    h  A   D    F  FH
# 6     9     i     56    j  A   D    F  FH
# 7    10     j      3    k  A   D    F  FH

# %%
import os

# %%
print(os.getcwd())
# Out:
# d:\programming\my pytoh learn\MACHINE LEARNING

# %%
c=pd.read_csv("D:\programming\my pytoh learn\pandas\ABHI.CSV",nrows=1)
c
# Out:
#    S NO TRAIN  SPEED CITY HI BYE COME  GO
# 0     1     A    120    X  A   D    F  FH

# %%
c=pd.read_csv("D:\programming\my pytoh learn\pandas\ABHI.CSV",header=1)
c
# Out:
#     1  A  120   X A.1  D  F  FH
# 0   2  B  110   Y   A  D  F  FH
# 1   3  C  100   Z   A  D  F  FH
# 2   4  D   90   W   A  D  F  FH
# 3   5  e   11  as   A  D  F  FH
# 4   6  f   23   d   A  D  F  FH
# 5   7  g   45   g   A  D  F  FH
# 6   8  h   33   h   A  D  F  FH
# 7   9  i   56   j   A  D  F  FH
# 8  10  j    3   k   A  D  F  FH

# %%
c.head()
# Out:
#    1  A  120   X A.1  D  F  FH
# 0  2  B  110   Y   A  D  F  FH
# 1  3  C  100   Z   A  D  F  FH
# 2  4  D   90   W   A  D  F  FH
# 3  5  e   11  as   A  D  F  FH
# 4  6  f   23   d   A  D  F  FH

# %%
c.head(3)
# Out:
#    1  A  120  X A.1  D  F  FH
# 0  2  B  110  Y   A  D  F  FH
# 1  3  C  100  Z   A  D  F  FH
# 2  4  D   90  W   A  D  F  FH

# %%
c.tail()
# Out:
#     1  A  120  X A.1  D  F  FH
# 4   6  f   23  d   A  D  F  FH
# 5   7  g   45  g   A  D  F  FH
# 6   8  h   33  h   A  D  F  FH
# 7   9  i   56  j   A  D  F  FH
# 8  10  j    3  k   A  D  F  FH

# %%
c=pd.read_csv("D:\programming\my pytoh learn\pandas\ABHI.CSV",header=1,dtype={'ID':'float64'})
c
# Out:
#     1  A  120   X A.1  D  F  FH
# 0   2  B  110   Y   A  D  F  FH
# 1   3  C  100   Z   A  D  F  FH
# 2   4  D   90   W   A  D  F  FH
# 3   5  e   11  as   A  D  F  FH
# 4   6  f   23   d   A  D  F  FH
# 5   7  g   45   g   A  D  F  FH
# 6   8  h   33   h   A  D  F  FH
# 7   9  i   56   j   A  D  F  FH
# 8  10  j    3   k   A  D  F  FH

# %%
c=pd.read_csv("D:\programming\my pytoh learn\pandas\ABHI.CSV",header=1,dtype={'ID':'float64'},true_values=['FH'])
c
# Out:
#     1  A  120   X A.1  D  F    FH
# 0   2  B  110   Y   A  D  F  True
# 1   3  C  100   Z   A  D  F  True
# 2   4  D   90   W   A  D  F  True
# 3   5  e   11  as   A  D  F  True
# 4   6  f   23   d   A  D  F  True
# 5   7  g   45   g   A  D  F  True
# 6   8  h   33   h   A  D  F  True
# 7   9  i   56   j   A  D  F  True
# 8  10  j    3   k   A  D  F  True
